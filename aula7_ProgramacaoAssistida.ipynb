# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriellabneves/engenharia_de_prompt_aplicacoes_ai/blob/main/aula7_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assistida
# Nome: Gabriella Barbosa, Cauã Spinola (Turma de sexta)

# %%
# Inicializa uma lista de números
numeros = [0, 1, 2, 3]

# Calcula a soma de todos os números na lista usando a função embutida sum()
soma = sum(numeros)

# Imprime a lista original de números
print(numeros)

# Imprime a soma calculada
print(soma)
# Out:
# [0, 1, 2, 3]
# 6

# %% [markdown]
# Eh Primo

# %%
nome=["g","a","b","i"]
