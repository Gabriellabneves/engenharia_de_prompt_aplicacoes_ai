# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriellabneves/engenharia_de_prompt_aplicacoes_ai/blob/main/CalculadoraSimples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calculadora Simples - Gabriella Barbosa

# %%
while True:
  try:
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))
    break
  except ValueError:
    print("Entrada inválida. Por favor, digite números válidos.")

print("Selecione a operação:")
print("1. Adição")
print("2. Subtração")
print("3. Multiplicação")
print("4. Divisão")

while True:
  escolha = input("Digite sua escolha (1/2/3/4): ")

  if escolha in ('1', '2', '3', '4'):
    if escolha == '1':
      print(f"{num1} + {num2} = {adicao(num1, num2)}")
    elif escolha == '2':
      print(f"{num1} - {num2} = {subtracao(num1, num2)}")
    elif escolha == '3':
      print(f"{num1} * {num2} = {multiplicacao(num1, num2)}")
    elif escolha == '4':
      print(f"{num1} / {num2} = {divisao(num1, num2)}")
    break
  else:
    print("Escolha inválida. Por favor, digite 1, 2, 3 ou 4.")
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 5
# Selecione a operação:
# 1. Adição
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# Digite sua escolha (1/2/3/4): 3
# 2.0 * 5.0 = 10.0
